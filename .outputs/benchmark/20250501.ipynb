# %%
from util import load_data, create_fixed_size_grid
all_data = load_data('./20250501')
# Out:
# Warning: ./20250501/fib_sp1-gpu.csv not found, skipping.
# Warning: ./20250501/sha2_sp1-gpu.csv not found, skipping.
# Warning: ./20250501/ecdsa_nexus.csv not found, skipping.
# Warning: ./20250501/ethtransfer_sp1-gpu.csv not found, skipping.
# Warning: ./20250501/ethtransfer_nexus.csv not found, skipping.
# Warning: ./20250501/ethtransfer_jolt.csv not found, skipping.

# %% [markdown]
# ## Machine Spec
#
# local Ubuntu 24.04 Desktop PC
# - 8 vCPUs
# - 192 GB RAM
# - 1 x NVIDIA RTX 5090
# - 32 GB GPU Memory

# %% [markdown]
# ## Project Overview
#
# |Project|Architecture|Proof System|Continuation|GPU Acceleration|
# |-|-|-|-|-|
# |SP1 v4.1.2|vRAM-style|FRI-STARK(Plonky3)|o|o|
# |RISC Zero v1.2.2|vRAM-style|FRI-STARK|o|o|
# |ZKM #262318f|vRAM-style|FRI-STARK(Plonky2)|o|x|
# |Novanet v0.1.0|vRAM-style|Nebula-Nova|o|x|
# |Ceno (not yet)|vRAM-style|GKR|o|x|
# |OpenVM v1.0.0-rc.2|Modular-style|FRI-STARK(Plonky3)|o|x|
# |Jolt v0.1.0|Modular-style|Lasso Lookup Argument|x|△|
# |Nexus v0.2.3|Modular-style|Nova|o|x|
# |Pico|Modular-style|FRI-STARK(Plonky3)|o|x|
#
# - vRAM-style: executes custom circuits defined for each type of instruction like CPU/Memory/Branch in data parallel.
# - Modular-style: executes custom circuits defined for each instruction such as add/mul/sw

# %% [markdown]
# ## Program vs Cycle Counts

# %%
all_data[["project","program","size","cycle"]]
# Out:
#          program
# 0            fib
# 1            fib
# 2            fib
# 3            fib
# 4            fib
# ..           ...
# 100  ethtransfer
# 101  ethtransfer
# 102  ethtransfer
# 103  ethtransfer
# 104  ethtransfer
#
# [105 rows x 1 columns]

# %% [markdown]
# ## E2E Comparison (Proof Duration, Verify Duration, Proof Size, Peak Memory)

# %%
create_fixed_size_grid(all_data)

# %% [markdown]
# ## Scalability Curve
